# %%
import sys
import numpy as np

sys.path.append("/mnt/lareaulab/reliscu/code")

from parse_gtf import *

# %% [markdown]
# ## Get module eigengenes for cell types of interest

# %%
ctype_abund_df = pd.read_csv("data/ctype_abundance/GTEx_cortex_counts_TMMF_All_501_outliers_removed_top_Qval_mods_PC1_ctype_abundance_filtered_47840genes_cleaned_44846genes_cleaned_mergeParam0.85_subsetCutoff1.427_Modules_top_corr_enriched_w_Claude_marker_genes_PC1_ctype_abundance.csv", index_col=0)

# %%
data_source = "GTEx_cortex_counts_TMMF_All_501_outliers_removed_top_Qval_mods_PC1_ctype_abundance_filtered_47840genes_cleaned_44846genes_cleaned_mergeParam0.85_subsetCutoff1.427_Modules_top_corr_enriched_w_Claude_marker_genes_PC1_ctype_abundance"

# %%
ctype_abund_df.head()
# Out:
#                                CGE Class  All GABAergic  \
# Sample
# GTEX.12126.0011.R10b.SM.5BC6T   0.144676       0.078921
# GTEX.12126.0011.R3b.SM.GJ3RE   -0.014015       0.041221
# GTEX.12126.1026.SM.5P9JJ        0.011209       0.051763
# GTEX.12WSE.0011.R3a.SM.GIN9S    0.079146       0.146882
# GTEX.15ER7.0011.R3a.SM.6LPIK    0.020049       0.049447
#
#                                Deep layer glutamatergic  All Neuronal  \
# Sample
# GTEX.12126.0011.R10b.SM.5BC6T                 -0.044717     -0.009510
# GTEX.12126.0011.R3b.SM.GJ3RE                   0.045162     -0.008888
# GTEX.12126.1026.SM.5P9JJ                       0.065797      0.062719
# GTEX.12WSE.0011.R3a.SM.GIN9S                  -0.003168      0.041387
# GTEX.15ER7.0011.R3a.SM.6LPIK                  -0.024795     -0.023440
#
#                                   Oligo      Endo      Peri       OPC  \
# Sample
# GTEX.12126.0011.R10b.SM.5BC6T -0.051565 -0.051868 -0.036232 -0.012470
# GTEX.12126.0011.R3b.SM.GJ3RE  -0.027182 -0.066528 -0.067439  0.001876
# GTEX.12126.1026.SM.5P9JJ      -0.010406 -0.008997  0.032106 -0.003790
# GTEX.12WSE.0011.R3a.SM.GIN9S  -0.036626 -0.028079  0.052985  0.046987
# GTEX.15ER7.0011.R3a.SM.6LPIK  -0.042440 -0.019883 -0.031119  0.007209
#
#                                   Astro  Micro/PVM      VLMC  \
# Sample
# GTEX.12126.0011.R10b.SM.5BC6T -0.020109  -0.026597 -0.013267
# GTEX.12126.0011.R3b.SM.GJ3RE  -0.024565  -0.034164 -0.016592
# GTEX.12126.1026.SM.5P9JJ      -0.030623  -0.010280  0.030002
# GTEX.12WSE.0011.R3a.SM.GIN9S   0.006512  -0.031341  0.004336
# GTEX.15ER7.0011.R3a.SM.6LPIK   0.005926  -0.030310 -0.012150
#
#                                Upper layer glutamatergic
# Sample
# GTEX.12126.0011.R10b.SM.5BC6T                   0.068628
# GTEX.12126.0011.R3b.SM.GJ3RE                   -0.010536
# GTEX.12126.1026.SM.5P9JJ                        0.077441
# GTEX.12WSE.0011.R3a.SM.GIN9S                    0.055599
# GTEX.15ER7.0011.R3a.SM.6LPIK                   -0.034865

# %% [markdown]
# ## Parse GTF (to annotate exons with their genes)

# %%
# Parse GTF attribute column
gtf_file = "/mnt/lareaulab/reliscu/data/GENCODE/GRCh38/gencode.v46.annotation.gtf"
gtf = gtf_parse(gtf_file)
gtf_subset = gtf.loc[gtf['feature'].isin(["gene"])]
attrs = gtf_subset["attribute"].apply(extract_attributes)
attrs_df = attrs.apply(pd.Series)
gtf_parsed = pd.concat([gtf_subset.drop(columns=["attribute"]), attrs_df], axis=1)
gtf_parsed['gene_id'] = gtf_parsed['gene_id'].str.split(".").str[0]

# %% [markdown]
# # PSI

# %%
psi = pd.read_csv(f"data/GTEx_cortex_exon_PSI.csv", index_col=0)
psi.columns = psi.columns.str.replace("-", ".")

# Make sure order of samples matches 
common = psi.columns.intersection(ctype_abund_df.index)
psi = psi[common]
ctype_abund_df = ctype_abund_df.loc[common]

# %%
# Get PSI data ready to merge on gene IDs
psi['gene_id'] = psi.index.str.split("_").str[0]
psi['exon_id'] = psi.index.values

psi_anno = pd.merge(gtf_parsed[['gene_id', 'gene_name']], psi, on="gene_id", how="right")
psi_anno = psi_anno.set_index("exon_id").rename_axis(None)
psi_anno = psi_anno.drop(columns=["gene_id"])

# %%
psi_anno[psi_anno['gene_name'] == "RPS24"]
# Out:
#                                 gene_name  GTEX.1117F.0011.R10b.SM.GI4VE  \
# ENSG00000138326_ProteinCoding_1     RPS24                       0.175452
# ENSG00000138326_ProteinCoding_2     RPS24                       0.077371
# ENSG00000138326_other_1             RPS24                       0.997909
# ENSG00000138326_ProteinCoding_3     RPS24                       0.269043
# ENSG00000138326_ProteinCoding_4     RPS24                       0.155806
# ENSG00000138326_ProteinCoding_6     RPS24                       0.998741
# ENSG00000138326_other_2             RPS24                       1.000000
# ENSG00000138326_NMD_1               RPS24                       0.666667
# ENSG00000138326_ProteinCoding_7     RPS24                       0.791892
#
#                                  GTEX.1117F.3226.SM.5N9CT  \
# ENSG00000138326_ProteinCoding_1                  0.182668
# ENSG00000138326_ProteinCoding_2                  0.070374
# ENSG00000138326_other_1                          0.997006
# ENSG00000138326_ProteinCoding_3                  0.227065
# ENSG00000138326_ProteinCoding_4                  0.131494
# ENSG00000138326_ProteinCoding_6                  0.998259
# ENSG00000138326_other_2                          1.000000
# ENSG00000138326_NMD_1                            1.000000
# ENSG00000138326_ProteinCoding_7                  0.760709
#
#                                  GTEX.111FC.0011.R10a.SM.GIN8G  \
# ENSG00000138326_ProteinCoding_1                       0.201022
# ENSG00000138326_ProteinCoding_2                       0.091380
# ENSG00000138326_other_1                               0.998017
# ENSG00000138326_ProteinCoding_3                       0.372479
# ENSG00000138326_ProteinCoding_4                       0.223742
# ENSG00000138326_ProteinCoding_6                       0.998702
# ENSG00000138326_other_2                               1.000000
# ENSG00000138326_NMD_1                                 0.000000
# ENSG00000138326_ProteinCoding_7                       0.925441
#
#                                  GTEX.111FC.0011.R3b.SM.GJ3PN  \
# ENSG00000138326_ProteinCoding_1                      0.170259
# ENSG00000138326_ProteinCoding_2                      0.039288
# ENSG00000138326_other_1                              0.999155
# ENSG00000138326_ProteinCoding_3                      0.148846
# ENSG00000138326_ProteinCoding_4                      0.080980
# ENSG00000138326_ProteinCoding_6                      0.999551
# ENSG00000138326_other_2                              0.750000
# ENSG00000138326_NMD_1                                0.333333
# ENSG00000138326_ProteinCoding_7                      0.780220
#
#                                  GTEX.1128S.2726.SM.5H12C  \
# ENSG00000138326_ProteinCoding_1                  0.183888
# ENSG00000138326_ProteinCoding_2                  0.095238
# ENSG00000138326_other_1                          0.995807
# ENSG00000138326_ProteinCoding_3                  0.348678
# ENSG00000138326_ProteinCoding_4                  0.210448
# ENSG00000138326_ProteinCoding_6                  0.997361
# ENSG00000138326_other_2                          1.000000
# ENSG00000138326_NMD_1                            1.000000
# ENSG00000138326_ProteinCoding_7                  0.849287
#
#                                  GTEX.117XS.0011.R10b.SM.GIN8Z  \
# ENSG00000138326_ProteinCoding_1                       0.177075
# ENSG00000138326_ProteinCoding_2                       0.088332
# ENSG00000138326_other_1                               0.999263
# ENSG00000138326_ProteinCoding_3                       0.391114
# ENSG00000138326_ProteinCoding_4                       0.240173
# ENSG00000138326_ProteinCoding_6                       0.999514
# ENSG00000138326_other_2                               0.714286
# ENSG00000138326_NMD_1                                 0.500000
# ENSG00000138326_ProteinCoding_7                       0.926301
#
#                                  GTEX.117XS.0011.R3a.SM.GIN8W  \
# ENSG00000138326_ProteinCoding_1                      0.176572
# ENSG00000138326_ProteinCoding_2                      0.039523
# ENSG00000138326_other_1                              0.996487
# ENSG00000138326_ProteinCoding_3                      0.137829
# ENSG00000138326_ProteinCoding_4                      0.072824
# ENSG00000138326_ProteinCoding_6                      0.998101
# ENSG00000138326_other_2                              1.000000
# ENSG00000138326_NMD_1                                1.000000
# ENSG00000138326_ProteinCoding_7                      0.747945
#
#                                  GTEX.117XS.3026.SM.5N9CA  \
# ENSG00000138326_ProteinCoding_1                  0.163573
# ENSG00000138326_ProteinCoding_2                  0.074360
# ENSG00000138326_other_1                          0.997208
# ENSG00000138326_ProteinCoding_3                  0.330208
# ENSG00000138326_ProteinCoding_4                  0.195710
# ENSG00000138326_ProteinCoding_6                  0.998266
# ENSG00000138326_other_2                          0.666667
# ENSG00000138326_NMD_1                            1.000000
# ENSG00000138326_ProteinCoding_7                  0.889353
#
#                                  GTEX.1192W.0011.R10b.SM.GHWOF  ...  \
# ENSG00000138326_ProteinCoding_1                       0.189238  ...
# ENSG00000138326_ProteinCoding_2                       0.044669  ...
# ENSG00000138326_other_1                               1.000000  ...
# ENSG00000138326_ProteinCoding_3                       0.161672  ...
# ENSG00000138326_ProteinCoding_4                       0.086907  ...
# ENSG00000138326_ProteinCoding_6                       1.000000  ...
# ENSG00000138326_other_2                               0.000000  ...
# ENSG00000138326_NMD_1                                 0.000000  ...
# ENSG00000138326_ProteinCoding_7                       0.787611  ...
#
#                                  GTEX.ZVT3.0011.R3b.SM.51MTJ  \
# ENSG00000138326_ProteinCoding_1                     0.177458
# ENSG00000138326_ProteinCoding_2                     0.041716
# ENSG00000138326_other_1                             0.989765
# ENSG00000138326_ProteinCoding_3                     0.147946
# ENSG00000138326_ProteinCoding_4                     0.078214
# ENSG00000138326_ProteinCoding_6                     0.994369
# ENSG00000138326_other_2                             0.857143
# ENSG00000138326_NMD_1                               1.000000
# ENSG00000138326_ProteinCoding_7                     0.764023
#
#                                  GTEX.ZVT3.3026.SM.5E43N  \
# ENSG00000138326_ProteinCoding_1                 0.140830
# ENSG00000138326_ProteinCoding_2                 0.061913
# ENSG00000138326_other_1                         0.996255
# ENSG00000138326_ProteinCoding_3                 0.292257
# ENSG00000138326_ProteinCoding_4                 0.170430
# ENSG00000138326_ProteinCoding_6                 0.997744
# ENSG00000138326_other_2                         0.750000
# ENSG00000138326_NMD_1                           0.428571
# ENSG00000138326_ProteinCoding_7                 0.859750
#
#                                  GTEX.ZVZQ.0011.R10b.SM.51MRT  \
# ENSG00000138326_ProteinCoding_1                      0.150424
# ENSG00000138326_ProteinCoding_2                      0.051731
# ENSG00000138326_other_1                              0.992659
# ENSG00000138326_ProteinCoding_3                      0.243797
# ENSG00000138326_ProteinCoding_4                      0.142907
# ENSG00000138326_ProteinCoding_6                      0.995801
# ENSG00000138326_other_2                              1.000000
# ENSG00000138326_NMD_1                                0.000000
# ENSG00000138326_ProteinCoding_7                      0.859719
#
#                                  GTEX.ZVZQ.2926.SM.GPI93  \
# ENSG00000138326_ProteinCoding_1                 0.205365
# ENSG00000138326_ProteinCoding_2                 0.059267
# ENSG00000138326_other_1                         0.995828
# ENSG00000138326_ProteinCoding_3                 0.151741
# ENSG00000138326_ProteinCoding_4                 0.083625
# ENSG00000138326_ProteinCoding_6                 0.997730
# ENSG00000138326_other_2                         1.000000
# ENSG00000138326_NMD_1                           1.000000
# ENSG00000138326_ProteinCoding_7                 0.673414
#
#                                  GTEX.ZXG5.0011.R10a.SM.57WDD  \
# ENSG00000138326_ProteinCoding_1                      0.165295
# ENSG00000138326_ProteinCoding_2                      0.064935
# ENSG00000138326_other_1                              0.994992
# ENSG00000138326_ProteinCoding_3                      0.260332
# ENSG00000138326_ProteinCoding_4                      0.150898
# ENSG00000138326_ProteinCoding_6                      0.997080
# ENSG00000138326_other_2                              1.000000
# ENSG00000138326_NMD_1                                0.000000
# ENSG00000138326_ProteinCoding_7                      0.829333
#
#                                  GTEX.ZYFD.0011.R3b.SM.GPRX3  \
# ENSG00000138326_ProteinCoding_1                     0.121540
# ENSG00000138326_ProteinCoding_2                     0.023378
# ENSG00000138326_other_1                             0.997642
# ENSG00000138326_ProteinCoding_3                     0.122500
# ENSG00000138326_ProteinCoding_4                     0.065832
# ENSG00000138326_ProteinCoding_6                     0.998818
# ENSG00000138326_other_2                             0.600000
# ENSG00000138326_NMD_1                               0.428571
# ENSG00000138326_ProteinCoding_7                     0.810526
#
#                                  GTEX.ZYFD.3026.SM.5E44C  \
# ENSG00000138326_ProteinCoding_1                 0.160554
# ENSG00000138326_ProteinCoding_2                 0.055260
# ENSG00000138326_other_1                         0.993170
# ENSG00000138326_ProteinCoding_3                 0.267991
# ENSG00000138326_ProteinCoding_4                 0.155357
# ENSG00000138326_ProteinCoding_6                 0.996059
# ENSG00000138326_other_2                         1.000000
# ENSG00000138326_NMD_1                           0.428571
# ENSG00000138326_ProteinCoding_7                 0.893939
#
#                                  GTEX.ZYY3.0011.R3a.SM.GQ1CX  \
# ENSG00000138326_ProteinCoding_1                     0.215983
# ENSG00000138326_ProteinCoding_2                     0.045578
# ENSG00000138326_other_1                             0.994072
# ENSG00000138326_ProteinCoding_3                     0.131821
# ENSG00000138326_ProteinCoding_4                     0.069679
# ENSG00000138326_ProteinCoding_6                     0.996797
# ENSG00000138326_other_2                             0.818182
# ENSG00000138326_NMD_1                               0.500000
# ENSG00000138326_ProteinCoding_7                     0.725424
#
#                                  GTEX.ZYY3.3126.SM.5MR6M  \
# ENSG00000138326_ProteinCoding_1                 0.170688
# ENSG00000138326_ProteinCoding_2                 0.052275
# ENSG00000138326_other_1                         0.970558
# ENSG00000138326_ProteinCoding_3                 0.214888
# ENSG00000138326_ProteinCoding_4                 0.123824
# ENSG00000138326_ProteinCoding_6                 0.983490
# ENSG00000138326_other_2                         0.935484
# ENSG00000138326_NMD_1                           1.000000
# ENSG00000138326_ProteinCoding_7                 0.833605
#
#                                  GTEX.ZZPT.0011.R10b.SM.GPI8B
# ENSG00000138326_ProteinCoding_1                      0.192186
# ENSG00000138326_ProteinCoding_2                      0.079858
# ENSG00000138326_other_1                              0.955838
# ENSG00000138326_ProteinCoding_3                      0.304899
# ENSG00000138326_ProteinCoding_4                      0.175291
# ENSG00000138326_ProteinCoding_6                      0.972203
# ENSG00000138326_other_2                              1.000000
# ENSG00000138326_NMD_1                                0.000000
# ENSG00000138326_ProteinCoding_7                      0.858951
#
# [9 rows x 502 columns]

# %%
# import matplotlib.pyplot as plt
# import pandas as pd

# x = pd.to_numeric(psi_anno.loc['ENSG00000138326_ProteinCoding_1'], errors='coerce')
# y = pd.to_numeric(psi_anno.loc['ENSG00000138326_ProteinCoding_2'], errors='coerce')

# plt.scatter(x, y)
# plt.show()

# %%
# psi_anno.loc['ENSG00000140988_ProteinCoding_1'].astype("float64")

# %%
# Correlate each cell type with all PSI events across samples

psi_numeric = psi_anno.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

psi_corr_results = {}
for ct in ctype_abund_df.columns:
    psi_corr_results[ct] = psi_numeric.T.corrwith(ctype_abund_df[ct])

psi_corr_df = pd.DataFrame(psi_corr_results)
psi_corr_df.insert(0, 'Gene', psi_anno['gene_name'])
# Out:
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
psi_corr_df.to_csv(f"data/corrs/{data_source}_exon_PSI_corr.csv")

# %% [markdown]
# # Counts

# %%
counts = pd.read_csv(f"data/GTEx_cortex_exon_counts.csv", index_col=0)
counts.columns = counts.columns.str.replace("-", ".")

# Make sure order of samples matches
common = counts.columns.intersection(ctype_abund_df.index)
counts = counts[common]
ctype_abund_df = ctype_abund_df.loc[common]

# %%
ctype_abund_df.shape
# Out:
# (501, 12)

# %%
# Get PSI and GTF data ready to merge on gene IDs
counts['gene_id'] = counts.index.str.split("_").str[0]
counts['exon_id'] = counts.index.values
counts_anno = pd.merge(gtf_parsed[['gene_id', 'gene_name']], counts, on="gene_id", how="right")
counts_anno = counts_anno.set_index("exon_id").rename_axis(None)
counts_anno = counts_anno.drop(columns=["gene_id"])

# Correlate each cell type with exon counts

counts_numeric = counts_anno.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

corr_results = {}
for ct in ctype_abund_df.columns:
    corr_results[ct] = counts_numeric.T.corrwith(ctype_abund_df[ct])

corr_df = pd.DataFrame(corr_results)
corr_df.insert(0, 'Gene', counts_anno['gene_name'])
# Out:
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /mnt/lareaulab/reliscu/anaconda3/envs/anndata/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
corr_df.tail()
# Out:
#                                    Gene  CGE Class  All GABAergic  \
# ENSG00000155962_other_2           CLIC2   0.043853       0.060651
# ENSG00000124333_ProteinCoding_1   VAMP7   0.479061       0.645417
# ENSG00000124333_ProteinCoding_2   VAMP7   0.498950       0.685315
# ENSG00000124334_ProteinCoding_1    IL9R   0.022977       0.030601
# ENSG00000182484_ProteinCoding_1  WASH6P   0.231153       0.284734
#
#                                  Deep layer glutamatergic  All Neuronal  \
# ENSG00000155962_other_2                          0.085269      0.152936
# ENSG00000124333_ProteinCoding_1                  0.275318      0.579811
# ENSG00000124333_ProteinCoding_2                  0.307211      0.640645
# ENSG00000124334_ProteinCoding_1                  0.025875     -0.032915
# ENSG00000182484_ProteinCoding_1                  0.197912      0.440660
#
#                                     Oligo      Endo      Peri       OPC  \
# ENSG00000155962_other_2          0.139914  0.421942  0.255490  0.168193
# ENSG00000124333_ProteinCoding_1  0.013343 -0.034423 -0.138353  0.157383
# ENSG00000124333_ProteinCoding_2  0.068934 -0.033802 -0.095495  0.225826
# ENSG00000124334_ProteinCoding_1 -0.005313  0.046322  0.016725  0.043137
# ENSG00000182484_ProteinCoding_1  0.089929 -0.020498 -0.061252 -0.032023
#
#                                     Astro  Micro/PVM      VLMC  \
# ENSG00000155962_other_2          0.068312   0.327569  0.394517
# ENSG00000124333_ProteinCoding_1  0.081824   0.337330 -0.043102
# ENSG00000124333_ProteinCoding_2  0.109744   0.322322 -0.025900
# ENSG00000124334_ProteinCoding_1  0.032689   0.034725  0.016167
# ENSG00000182484_ProteinCoding_1 -0.052137   0.056050 -0.025107
#
#                                  Upper layer glutamatergic
# ENSG00000155962_other_2                           0.077746
# ENSG00000124333_ProteinCoding_1                   0.379344
# ENSG00000124333_ProteinCoding_2                   0.412328
# ENSG00000124334_ProteinCoding_1                  -0.067647
# ENSG00000182484_ProteinCoding_1                   0.355219

# %%
corr_df.to_csv(f"data/corrs/{data_source}_exon_counts_corr.csv")

# %% [markdown]
# # Gene expr

# %%
bulk_expr = pd.read_csv("GTEx_cortex_counts_TMMF_SampleNetworks/All_02-25-12/GTEx_cortex_counts_TMMF_All_501_outliers_removed.csv")
bulk_expr.columns.values[0] = "Gene"

# %%
bulk_expr.head()
# Out:
#           Gene  GTEX.111FC.0011.R3b.SM.GJ3PN  GTEX.117XS.0011.R3a.SM.GIN8W  \
# 0      DDX11L1                      0.000000                      0.000000
# 1       WASH7P                    122.349063                    172.427568
# 2    MIR6859-1                      0.000000                      0.000000
# 3  MIR1302-2HG                      1.699293                      0.000000
# 4      FAM138A                      0.000000                      0.000000
#
#    GTEX.1192X.0011.R3b.SM.GIN8Y  GTEX.11DXW.0011.R3b.SM.DNZZE  \
# 0                      0.000000                      0.000000
# 1                    130.200106                     47.386638
# 2                      0.000000                      0.000000
# 3                      0.000000                      0.000000
# 4                      0.000000                      2.016453
#
#    GTEX.11GS4.0011.R3b.SM.GJ3RI  GTEX.11GSO.0011.R3b.SM.57WB2  \
# 0                      0.000000                      0.000000
# 1                    103.159575                     36.389517
# 2                      0.000000                      0.000000
# 3                      0.000000                      0.933065
# 4                      0.000000                      0.000000
#
#    GTEX.11GSP.0011.R3a.SM.9QEGF  GTEX.11NUK.0011.R3b.SM.GJ3RO  \
# 0                      1.356930                      0.000000
# 1                     56.991057                     86.216952
# 2                      0.000000                      0.000000
# 3                      1.356930                      0.000000
# 4                      0.000000                      0.000000
#
#    GTEX.11NV4.0011.R3b.SM.GINAJ  ...  GTEX.XLM4.0011.R10A.SM.4AT5P  \
# 0                      0.000000  ...                      0.000000
# 1                    177.210769  ...                     50.181401
# 2                      0.000000  ...                      0.000000
# 3                      0.000000  ...                      0.000000
# 4                      0.000000  ...                      0.000000
#
#    GTEX.Y8DK.0011.R10A.SM.4SOK1  GTEX.YJ89.0011.R10a.SM.4SOK9  \
# 0                      0.000000                      0.000000
# 1                     83.575447                     71.959244
# 2                      0.000000                      0.000000
# 3                      2.785848                      0.000000
# 4                      0.000000                      0.000000
#
#    GTEX.ZF28.0011.R10a.SM.4WWEH  GTEX.ZUA1.0011.R10a.SM.51MT6  \
# 0                      0.903235                      0.000000
# 1                    110.194641                     53.158136
# 2                      0.000000                      0.000000
# 3                      0.903235                      0.000000
# 4                      2.709704                      0.000000
#
#    GTEX.ZV68.0011.R10a.SM.51MT7  GTEX.ZVT3.0011.R10b.SM.57WB6  \
# 0                      1.339780                      1.004289
# 1                     99.143705                     66.283074
# 2                      0.000000                      0.000000
# 3                      2.679560                      3.012867
# 4                      0.000000                      1.004289
#
#    GTEX.ZVZQ.0011.R10b.SM.51MRT  GTEX.ZXG5.0011.R10a.SM.57WDD  \
# 0                      0.948680                      0.000000
# 1                     79.689127                     62.121309
# 2                      0.000000                      0.000000
# 3                      1.897360                      1.380474
# 4                      0.000000                      0.000000
#
#    GTEX.ZZPT.0011.R10b.SM.GPI8B
# 0                      0.000000
# 1                     76.635758
# 2                      0.000000
# 3                      0.870861
# 4                      0.000000
#
# [5 rows x 502 columns]

# %%
# Remove duplicate genes by selecting row with highest mean expression

mean_expr = pd.DataFrame({
    'Index': range(len(bulk_expr)),
    'Gene': bulk_expr.iloc[:, 0],
    'Expr': bulk_expr.iloc[:, 1:].mean(axis=1)
})

keep = mean_expr.loc[mean_expr.groupby('Gene')['Expr'].idxmax(), 'Index']
bulk_expr_filtered = bulk_expr.iloc[keep.values]

# %%
# Filter 0 genes

mask = bulk_expr_filtered.iloc[:, 1:].mean(axis=1) > 0
bulk_expr_filtered = bulk_expr_filtered[mask]

# %%
bulk_expr_filtered = bulk_expr_filtered.set_index("Gene")
common = bulk_expr_filtered.columns.intersection(ctype_abund_df.index)
bulk_expr_filtered = bulk_expr_filtered[common]
ctype_abund_df = ctype_abund_df.loc[common]

# %%
ctype_abund_df.shape
# Out:
# (501, 12)

# %%
# Correlate each cell type with gene expression

expr_corr_results = {}
for ct in ctype_abund_df.columns:
    expr_corr_results[ct] = bulk_expr_filtered.T.corrwith(ctype_abund_df[ct])
    
expr_corr_df = pd.DataFrame(expr_corr_results)

# %%
expr_corr_df.head()
# Out:
#            CGE Class  All GABAergic  Deep layer glutamatergic  All Neuronal  \
# Gene
# 5S_rRNA     0.050017       0.113705                  0.037459      0.156236
# 5_8S_rRNA   0.092423       0.127862                  0.023519      0.063453
# 7SK         0.018007       0.064494                  0.055557      0.049035
# A1BG        0.385136       0.535027                  0.205803      0.432283
# A1BG-AS1    0.410480       0.573141                  0.466322      0.894040
#
#               Oligo      Endo      Peri       OPC     Astro  Micro/PVM  \
# Gene
# 5S_rRNA   -0.064105 -0.018881 -0.041302 -0.005345  0.019099   0.143568
# 5_8S_rRNA -0.015250  0.000352 -0.037311  0.020922  0.001660   0.074401
# 7SK        0.027884 -0.018118 -0.004496  0.026686  0.012173  -0.034212
# A1BG       0.200378  0.038310  0.100613  0.464258  0.224893   0.172073
# A1BG-AS1   0.060064 -0.209528 -0.234715 -0.189239 -0.342934  -0.059354
#
#                VLMC  Upper layer glutamatergic
# Gene
# 5S_rRNA   -0.060981                   0.090062
# 5_8S_rRNA -0.026247                   0.026789
# 7SK        0.102745                   0.008279
# A1BG      -0.036635                   0.251859
# A1BG-AS1  -0.016338                   0.688594

# %%
expr_corr_df.to_csv(f"data/corrs/{data_source}_gene_expr_corr.csv")
